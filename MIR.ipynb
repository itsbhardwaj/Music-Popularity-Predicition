# %%
import os.path
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
#import stanford_mir; stanford_mir.init()
from ipywidgets import interact
import math

# %%
path=os.path.join('\Projects\MIR', 'Sugar.mp3')

# %%
y,sr=librosa.load(path, sr=None)
sr
# Out:
# 44100

# %%
tempo, beat_frames = librosa.beat.beat_track(y, sr)
print('Estimated tempo: {:.2f} beats per minute'.format(math.ceil(tempo)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-9109b72d7cac> in <module>
#       1 tempo, beat_frames = librosa.beat.beat_track(y, sr)
# ----> 2 print('Estimated tempo: {:.2f} beats per minute'.format(math.round(tempo)))
#
# AttributeError: module 'math' has no attribute 'round'

# %%
# 4. Convert the frame indices of beat events into timestamps
beat_times = librosa.frames_to_time(beat_frames, sr=sr)
beat_times
# Out:
# array([ 0.03482993,  0.47600907,  0.92879819,  1.36997732,  1.84598639,
#         2.31038549,  2.77478458,  3.2275737 ,  3.69197279,  4.15637188,
#         4.62077098,  5.07356009,  5.53795918,  6.00235828,  6.46675737,
#         6.93115646,  7.38394558,  7.84834467,  8.31274376,  8.77714286,
#         9.22993197,  9.69433107, 10.15873016, 10.62312925, 11.07591837,
#        11.54031746, 12.00471655, 12.46911565, 12.92190476, 13.38630385,
#        13.85070295, 14.31510204, 14.76789116, 15.23229025, 15.69668934,
#        16.16108844, 16.61387755, 17.07827664, 17.54267574, 18.00707483,
#        18.45986395, 18.92426304, 19.38866213, 19.85306122, 20.31746032,
#        20.78185941, 21.23464853, 21.69904762, 22.15183673])

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, alpha=0.6)
plt.vlines(beat_times, -1, 1, color='r')
plt.ylim(-1, 1)
# Out:
# (-1, 1)

# %%
from __future__ import print_function
import librosa

# 1. Get the file path to the included audio example
filename = librosa.util.example_audio_file()

# 2. Load the audio as a waveform `y`
#    Store the sampling rate as `sr`
y, sr = librosa.load(filename)

# 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)

print('Estimated tempo: {:.2f} beats per minute'.format(tempo))

# 4. Convert the frame indices of beat events into timestamps
beat_times = librosa.frames_to_time(beat_frames, sr=sr)
