# %%
# import pandas as pd
import pandas as pd
loc="G:\Projects\Music-Popularity-Prediction\DataMining"

# %%
SongData = pd.read_csv(loc+"\SongsData.csv")

# %%
SongData.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
SongData
# Out:
#       acousticness  danceability  duration_ms  energy  explict  \
# 0          0.00112         0.652       202066   0.698    False
# 1          0.38000         0.866       199440   0.813    False
# 2          0.19200         0.695       215280   0.762    False
# 3          0.75100         0.501       182160   0.405    False
# 4          0.09060         0.499       229573   0.800    False
# 5          0.29100         0.719       194358   0.653    False
# 6          0.85800         0.331       228093   0.622     True
# 7          0.30100         0.790       171453   0.766    False
# 8          0.00987         0.601       217466   0.794    False
# 9          0.05270         0.683       158546   0.821    False
# 10         0.29700         0.786       178153   0.633    False
# 11         0.37400         0.693       211362   0.575    False
# 12         0.29600         0.674       178480   0.881    False
# 13         0.30000         0.688       193320   0.688    False
# ...

# %%
billboard = pd.read_csv(loc+"\BillboardHot100(2000-2019).csv")

# %%
billboard.drop(["Unnamed: 0"],axis=1,inplace=True)
billboard
# Out:
#       index                      artist  ranking                        song  \
# 0         0                  Faith Hill        1                     Breathe
# 1         1                     Santana        2                      Smooth
# 2         2                     Santana        3                 Maria Maria
# 3         3                         Joe        4                I Wanna Know
# 4         4            Vertical Horizon        5         Everything You Want
# 5         5             Destiny's Child        6                 Say My Name
# 6         6               Savage Garden        7          I Knew I Loved You
# 7         7                    Lonestar        8                      Amazed
# 8         8             Matchbox Twenty        9                        Bent
# 9         9                Toni Braxton       10        He Wasn't Man Enough
# 10       10                       Creed       11                      Higher
# ...

# %%
l=billboard["song"].tolist()

# %%
r1,_=SongData.shape
r2,_=billboard.shape
print(r1,r2)
# Out:
# 1132 1900

# %%
yCol=[]
for i in range(r1):
    if (SongData["name"][i] in l):
        yCol.append("y")
    else:
        yCol.append("n")

# %%
yCol
# Out:
# ['n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'y',
#  'y',
#  'y',
#  'n',
#  'n',
#  'n',
#  'y',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'y',
#  'y',
#  'y',
#  'y',
#  'y',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'y',
#  'y',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'n',
#  'n',
#  'y',
#  'n',
#  'y',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'y',
#  'y',
#  'n',
#  'y',
#  'n',
#  'n',
#  'y',
#  'y',
# ...

# %%
SongData["Hit"]=yCol

# %%
SongData
# Out:
#       acousticness  danceability  duration_ms  energy  explict  \
# 0          0.00112         0.652       202066   0.698    False
# 1          0.38000         0.866       199440   0.813    False
# 2          0.19200         0.695       215280   0.762    False
# 3          0.75100         0.501       182160   0.405    False
# 4          0.09060         0.499       229573   0.800    False
# 5          0.29100         0.719       194358   0.653    False
# 6          0.85800         0.331       228093   0.622     True
# 7          0.30100         0.790       171453   0.766    False
# 8          0.00987         0.601       217466   0.794    False
# 9          0.05270         0.683       158546   0.821    False
# 10         0.29700         0.786       178153   0.633    False
# 11         0.37400         0.693       211362   0.575    False
# 12         0.29600         0.674       178480   0.881    False
# 13         0.30000         0.688       193320   0.688    False
# ...

# %%
SongData.to_csv(loc+"\\SongsData.csv")

# %%
count=0
for i in yCol:
    if(i=="y"):
        count+=1

# %%
count
# Out:
# 424

# %%
len(yCol)
# Out:
# 1132

# %%
1490-657
# Out:
# 833
